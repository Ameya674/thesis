# %%
import pandas as pd

# %%
count_love = pd.read_csv("protests.csv")
count_love
# Out:
#              Date                           Location  Attendees  \
# 0      2017-01-15  Bowie State University, Bowie, MD     1500.0
# 1      2017-01-16                   Johnson City, TN      300.0
# 2      2017-01-16                   Indianapolis, IN       20.0
# 3      2017-01-16                     Cincinnati, OH        NaN
# 4      2017-01-18                       Hartford, CT      300.0
# ...           ...                                ...        ...
# 38092  2021-01-30      Washington Square, Ottawa, IL      100.0
# 38093  2021-01-31                         Topeka, KS        NaN
# 38094  2021-01-31                         Austin, TX       20.0
# 38095  2021-01-31                 Salt Lake City, UT        NaN
# 38096  2021-01-31                  San Francisco, CA      100.0
#
#                   Event (legacy; see tags)  \
# 0                               Healthcare
# 1                             Civil Rights
# 2                              Environment
# ...

# %% [markdown]
# ## Does this dataset have a variables that indicates what county the protest occured in?

# %%
count_love.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38097 entries, 0 to 38096
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      38097 non-null  object
#  1   Location                  38097 non-null  object
#  2   Attendees                 23036 non-null  float64
#  3   Event (legacy; see tags)  38097 non-null  object
#  4   Tags                      38097 non-null  object
#  5   Curated                   38097 non-null  object
#  6   Source                    38097 non-null  object
#  7   Total Articles            38097 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# #### Location seems to be the only column that could contain the county information

# %%
count_love.Location.value_counts()
# Out:
# Location
# Washington, DC                331
# New York, NY                  276
# Detroit, MI                   242
# Louisville, KY                231
# Portland, OR                  221
#                              ...
# Frost Park, Tacoma, WA          1
# Comerica Park, Detroit, MI      1
# Priceville, AL                  1
# Quincy Park, Arlington, VA      1
# Marlboro, NJ                    1
# Name: count, Length: 10037, dtype: int64

# %% [markdown]
# ## These are cities and not counties, this dataset does not contain the county level information required, hence this dataset cannot be considered for analysis
