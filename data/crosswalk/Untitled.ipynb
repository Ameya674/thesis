# %%
import pandas as pd

# %%
crosswalk = pd.read_csv("crosswalk_panel.csv", index_col = 0)

# %%
crosswalk.head()
# Out:
#          ori  county_fips  place_fips state_name county_name  \
# 0  AL0040200         1001        3220    ALABAMA     AUTAUGA
# 1  AL0040100         1001       62328    ALABAMA     AUTAUGA
# 2  AL0040300         1001       62328    ALABAMA     AUTAUGA
# 3  AL0040000         1001       99001    ALABAMA     AUTAUGA
# 4  AL0051100         1003        4660    ALABAMA     BALDWIN
#
#           place_name
# 0  AUTAUGAVILLE TOWN
# 1    PRATTVILLE CITY
# 2    PRATTVILLE CITY
# 3     AUTAUGA COUNTY
# 4   State of Alabama
